# %%
import numpy as np

# %%
np.load("./ExperimentWeights/2_1.npy")
# Out:
# array([[[ 3.6530814e-04, -3.1273395e-01],
#         [ 3.1324023e-01, -1.3990766e-04]]], dtype=float32)

# %%
np.load("./ExperimentWeights/2_15.npy")
# Out:
# array([[[ 1.1234351e-03, -3.1421843e-01],
#         [ 3.1481022e-01,  5.5450178e-05]]], dtype=float32)
