# %%
import numpy as np
import pickle
import os
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
from tqdm.auto import tqdm
from torch.utils.data import TensorDataset, DataLoader
from torch.distributions.normal import Normal
import torch.nn.functional as F
import gc
import math
import seaborn as sns

from util import *

# %%
r = np.random.uniform(low = 0,high = 1, size = 10000)
theta = np.random.uniform(low = 0,high = 2*np.pi, size = 10000)
X = r*np.cos(theta)

Y = r*np.sin(theta)


Data_original = np.concatenate([X[:,None],Y[:,None]],axis = -1)

plt.figure(figsize=(4,4))
plt.scatter(Data_original[:,0],Data_original[:,1], s= 0.5, label = "Original Data")
plt.grid("True")
plt.legend()
plt.title("Ground Truth")
# Out:
# Text(0.5, 1.0, 'Ground Truth')

# %%
# X_new = np.sign(X)*(np.abs(X.copy()))**(1/3) # Coordinate Perturbation
# Y_new = np.sign(Y)*(np.abs(Y.copy()))**(1/3) # Coordinate Perturbation

X_new = np.sign(X)*(np.abs(X.copy()))**(1/2) # Coordinate Perturbation
Y_new = np.sign(Y)*(np.abs(Y.copy()))**(1/2) # Coordinate Perturbation
Data_perturbed = np.concatenate([X_new[:,None],Y_new[:,None]],axis = -1)

plt.figure(figsize=(4,4))
plt.scatter(Data_original[:,0],Data_original[:,1], s= 0.5, label = "Original Data")
plt.scatter(Data_perturbed[:,0],Data_perturbed[:,1], s= 0.5, label = "Hidden Symmetry")
plt.grid("True")
plt.legend()

# %%
def psi(z):
    """
    The conserved charge in the new coordinate system
    """
    X_old_square = ((z[:,0])**2)**(2)
    Y_old_square = ((z[:,1])**2)**(2)
    
    return ( (X_old_square+Y_old_square) **0.5)[:,None]

# %%
# Complete supervised train technique
tensor_original = torch.Tensor(Data_original)
tensor_perturbed = torch.Tensor(Data_perturbed)

dataset = torch.utils.data.TensorDataset(tensor_original, tensor_perturbed)

train_ratio = 0.8
train_size = int(train_ratio * len(dataset))
test_size = len(dataset) - train_size

train_dataset, test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])

train_dataloader = DataLoader(train_dataset,
                              batch_size=512,
                              shuffle=True,
                              drop_last = True,
                              num_workers=8,
                              pin_memory = False)

test_dataloader = DataLoader(test_dataset,
                              batch_size=4096,
                              shuffle=True,
                              drop_last = True,
                              num_workers=8,
                              pin_memory = False)

device = "cuda:1"

# %%
NUM_GEN = 1
model_symmetry = Operator(feature_size=2,
                          feature_multipier=4,
                          number_of_blocks=4,
                          num_generators=NUM_GEN,
                          normalise_enc=True,
                          normalise_dec=False,
                          LOSS_MODE="MSE"
                         ).to(device)
optimiser_symmetry = torch.optim.Adam(model_symmetry.parameters(), lr = 1e-3)
# optimiser_symmetry = torch.optim.SGD(model_symmetry.parameters(), lr = 0.01)
scheduler_symmetry = torch.optim.lr_scheduler.ReduceLROnPlateau(optimiser_symmetry, mode='min', factor=0.1, patience=10, verbose=True)


model_symmetry = train_for_hidden_symmetry(train_dataloader = train_dataloader,
                                           visualisation_set = tensor_perturbed,
                                           optimiser_symmetry = optimiser_symmetry,
                                           model_symmetry = model_symmetry,
                                           psi = psi,
                                           NUM_GEN = NUM_GEN,
                                           device = device,
                                           verbose= True,
                                           NEpochs = 2000,
                             )
# Out:
# /global/homes/d/diptarko/.local/perlmutter/tensorflow2.12.0/lib/python3.9/site-packages/torch/nn/modules/lazy.py:180: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
#   0%|          | 0/2000 [00:00<?, ?it/s]
# EPOCH 0 complete
# =====================
# Symmetry Closure Loss  0.32730209628740947
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.9497175892194112
# Space Inversion Loss  0.31818148692448933
# Total loss 1.59520117243131
# EPOCH 100 complete
# =====================
# Symmetry Closure Loss  0.044372586409250896
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.7291580677032471
# Space Inversion Loss  0.03759489382306735
# Total loss 0.8111255479355653
# EPOCH 200 complete
# =====================
# Symmetry Closure Loss  0.01103059109300375
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.00015436410903930665
# Space Inversion Loss  0.0018490550806745886
# Total loss 0.013034010282717645
# EPOCH 300 complete
# =====================
# Symmetry Closure Loss  0.0017405713520323236
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.00026806294918060305
# Space Inversion Loss  0.00031591181565696996
# Total loss 0.0023245461168698964
# EPOCH 400 complete
# =====================
# Symmetry Closure Loss  0.000780511375827094
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.00010915001233418783
# Space Inversion Loss  0.0001591138056634615
# Total loss 0.0010487751938247432
# EPOCH 500 complete
# =====================
# Symmetry Closure Loss  0.0005622890021186322
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  9.542604287465414e-05
# Space Inversion Loss  0.00011386346013750881
# Total loss 0.0007715785051307951
# EPOCH 600 complete
# =====================
# Symmetry Closure Loss  0.0004269316462644686
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.00013087689876556396
# Space Inversion Loss  8.572793109730507e-05
# Total loss 0.0006435364761273375
# EPOCH 700 complete
# =====================
# Symmetry Closure Loss  0.00037018303798201185
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.0001085907220840454
# Space Inversion Loss  0.00010707626352086663
# Total loss 0.0005858500235869238
# EPOCH 800 complete
# =====================
# Symmetry Closure Loss  0.0002782066507885853
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.00018665591875712076
# Space Inversion Loss  6.245779974657731e-05
# Total loss 0.0005273203692922833
# EPOCH 900 complete
# =====================
# Symmetry Closure Loss  0.00027007769385818393
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.0001892546812693278
# Space Inversion Loss  7.092591622495092e-05
# Total loss 0.0005302582913524627
# EPOCH 1000 complete
# =====================
# Symmetry Closure Loss  0.00023298083591119696
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  6.147325038909912e-05
# Space Inversion Loss  5.3393184983481964e-05
# Total loss 0.0003478472712837781
# EPOCH 1100 complete
# =====================
# Symmetry Closure Loss  0.00023404061697268236
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.000135497252146403
# Space Inversion Loss  6.184411589250279e-05
# Total loss 0.00043138198501158813
# EPOCH 1200 complete
# =====================
# Symmetry Closure Loss  0.00020889753262357165
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.00016452670097351075
# Space Inversion Loss  5.176151219833021e-05
# Total loss 0.00042518574579541264
# EPOCH 1300 complete
# =====================
# Symmetry Closure Loss  0.00018729686465424796
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.00017162561416625977
# Space Inversion Loss  4.2651084610649076e-05
# Total loss 0.0004015735634311568
# EPOCH 1400 complete
# =====================
# Symmetry Closure Loss  0.0002037238407259186
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.00025704304377237953
# Space Inversion Loss  7.004378300431805e-05
# Total loss 0.0005308106675026162
# EPOCH 1500 complete
# =====================
# Symmetry Closure Loss  0.0001651027036132291
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.00025744338830312093
# Space Inversion Loss  4.806666135361108e-05
# Total loss 0.00047061275326996114
# EPOCH 1600 complete
# =====================
# Symmetry Closure Loss  0.0001333483902271837
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.0002595732609430949
# Space Inversion Loss  3.539109590443938e-05
# Total loss 0.000428312747074718
# EPOCH 1700 complete
# =====================
# Symmetry Closure Loss  0.00012011846217016378
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.00016677876313527426
# Space Inversion Loss  3.0151392760065695e-05
# Total loss 0.00031704861806550373
# EPOCH 1800 complete
# =====================
# Symmetry Closure Loss  0.0001025396995828487
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  0.000135992964108785
# Space Inversion Loss  2.5748402549652383e-05
# Total loss 0.0002642810662412861
# EPOCH 1900 complete
# =====================
# Symmetry Closure Loss  0.00011425737466197461
# Symmetry Orthogonality Loss  0
# Symmetry Collapse Loss  8.836587270100911e-05
# Space Inversion Loss  4.0432955817474676e-05
# Total loss 0.0002430562031804584

# %% [markdown]
# ### Looking at specific examples

# %%
perturbed = tensor_perturbed[:1024,:].to(device)
theta = [(0.05*torch.ones(perturbed.shape[0],device = device)) for i in range(NUM_GEN)]  #Sampling

enc, trans, dec, dec_trans = model_symmetry(Z = perturbed,
                                            theta = theta)

original = perturbed.to("cpu").detach()
transformed = dec_trans.to("cpu").detach()

plt.scatter(original[:,0],original[:,1],s=1)
plt.scatter(transformed[:,0],transformed[:,1],s=1)

# %%
plt.figure(figsize=(8, 8))
magni = 1
dx = transformed[:600, 0] - original[:600, 0]
dy = transformed[:600, 1] - original[:600, 1]
plt.quiver(original[:600, 0], original[:600, 1], magni*dx, magni*dy, angles='xy', scale_units='xy', scale=1, width=0.002, alpha=1, color='black')

plt.legend()
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Flow Plot: Original to Transformed Points")
# plt.axis('equal')
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
r = 1
theta = np.arange(0,2*np.pi,0.2)
X = r*np.cos(theta)
Y = r*np.sin(theta)

X_new = np.sign(X)*(np.abs(X.copy()))**(1/2) # Coordinate Perturbation
Y_new = np.sign(Y)*(np.abs(Y.copy()))**(1/2) # Coordinate Perturbation
Data_vis = torch.Tensor(np.concatenate([X_new[:,None],Y_new[:,None]],axis = -1))

theta = [(0.05*torch.ones(Data_vis.shape[0],device = device)) for i in range(NUM_GEN)]  #Sampling

enc, trans, dec, dec_trans = model_symmetry(Z = Data_vis.to(device),
                                            theta = theta)

original = Data_vis.detach()
transformed = dec_trans.to("cpu").detach()

plt.figure(figsize=(8, 8))
magni = 1
dx = transformed[:, 0] - original[:, 0]
dy = transformed[:, 1] - original[:, 1]
plt.quiver(original[:, 0], original[:, 1], magni*dx, magni*dy, angles='xy', scale_units='xy', scale=1, width=0.004, alpha=1, color='black')
plt.scatter(enc[:,0].detach().cpu(),enc[:,1].detach().cpu())
plt.legend()
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Flow Plot: Original to Transformed Points")
plt.axis('equal')
plt.grid(True)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
